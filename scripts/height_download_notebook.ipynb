# %% [markdown]
# # Documentation for downloading height datasets

# %% [markdown]
# General dataset: Actueel Hoogtebestand Nederland (AHN2)
#
# This script is used to download the content of all datasets which are on the page : https://www.pdok.nl/downloads?articleid=1948857
#
#
# These datasets have the shape of an xml file which contains many links to the files we are looking for.

# %% [markdown]
# ## Import libraries

# %%
import requests
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import subprocess

# %% [markdown]
# ## Set variables

# %%
download_links = [] #Contains links of xml files that we need to go through
datasets_links = {} #Contains all the datasets and files associated to each datasets

# %% [markdown]
# ## Define the functions

# %%
def extract_dataset_from_link(dataset_xml_link):
    """
    This function creates a dictionary with an association between a file name and its download link
    The input is a link of a xml file
    The output is file_and_link 
    """
    file_and_link = {}
    zip_link = ''
    id = ''

    xml_page = requests.get(dataset_xml_link)
    root = ET.fromstring(xml_page.text)

    #Fill data into a dictionary (name : link)
    for child in root:
        for elt in child:
            if elt.tag[-2:] == 'id':
                id = elt.text[:-8]
            if elt.tag[-4:] == 'link' and elt.attrib.get('type') == "application/x-compressed":
                zip_link = elt.attrib.get('href')
            #Map id and link
            if(id != '' and zip_link != ''):
                file_and_link[id] = zip_link

    return file_and_link

# %%
def call_script_sh(filename, url):
    """
    This function calls an shell script on the server
    This shell script download the dataset into /data/height repertory on the server
    The file downloaded is a .zip
    """
    process = subprocess.Popen(['./dl.sh',filename, url], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    stdout, stderr = process.communicate()
    #print(stdout)

# %% [markdown]
# ## Analysis of the webpage

# %%
#Get content of the web page where we can see all the dataset
datasets_page = requests.get("https://www.pdok.nl/downloads?articleid=1948857")

# %%
#Create beautiful Object
soup_html = BeautifulSoup(datasets_page.text,"html.parser")

#Looking for HTML attributes which contain XML links 
download_link_containers = soup_html.find_all('a', class_ = 'btn btn-action btn-download btn-download-width')

#Extract the XML link from the HTML attribute
for link in download_link_containers:
    download_links.append(link.get("href"))

# %%
download_links
# Out:
# ['http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_05m_int.xml',
#  'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_05m_non.xml',
#  'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_05m_ruw.xml',
#  'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_5m.xml',
#  'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_gefilterd.xml',
#  'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_uitgefilterd.xml']

# %% [markdown]
# ## Map a dataset with the files it contain

# %%
#Map an xml and all the file it contain
for xml_link in download_links:
    extract = extract_dataset_from_link(xml_link)
    datasets_links[xml_link] = extract

# %% [markdown]
# ## Structure of the data we get

# %%
datasets_links
# Out:
# {'http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_05m_int.xml': {'i01cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01cz1.tif.zip',
#   'i01cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01cz2.tif.zip',
#   'i01dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01dz1.tif.zip',
#   'i01dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01dz2.tif.zip',
#   'i01gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01gn1.tif.zip',
#   'i01gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01gn2.tif.zip',
#   'i01gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01gz1.tif.zip',
#   'i01gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01gz2.tif.zip',
#   'i01hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01hn1.tif.zip',
#   'i01hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01hn2.tif.zip',
#   'i01hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01hz1.tif.zip',
#   'i01hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i01hz2.tif.zip',
#   'i02cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02cn1.tif.zip',
#   'i02cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02cn2.tif.zip',
#   'i02cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02cz1.tif.zip',
#   'i02cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02cz2.tif.zip',
#   'i02dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02dn1.tif.zip',
#   'i02dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02dz1.tif.zip',
#   'i02dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02dz2.tif.zip',
#   'i02ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02ez1.tif.zip',
#   'i02ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02ez2.tif.zip',
#   'i02fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02fz1.tif.zip',
#   'i02fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02fz2.tif.zip',
#   'i02gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02gn1.tif.zip',
#   'i02gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02gn2.tif.zip',
#   'i02gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02gz1.tif.zip',
#   'i02gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02gz2.tif.zip',
#   'i02hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02hn1.tif.zip',
#   'i02hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02hn2.tif.zip',
#   'i02hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02hz1.tif.zip',
#   'i02hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i02hz2.tif.zip',
#   'i03az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03az1.tif.zip',
#   'i03cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03cz1.tif.zip',
#   'i03cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03cz2.tif.zip',
#   'i03dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03dn1.tif.zip',
#   'i03dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03dn2.tif.zip',
#   'i03dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03dz1.tif.zip',
#   'i03dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03dz2.tif.zip',
#   'i03gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03gn1.tif.zip',
#   'i03gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03gn2.tif.zip',
#   'i03gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03gz1.tif.zip',
#   'i03gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03gz2.tif.zip',
#   'i03hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03hn1.tif.zip',
#   'i03hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03hz1.tif.zip',
#   'i03hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i03hz2.tif.zip',
#   'i04dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04dn2.tif.zip',
#   'i04dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04dz2.tif.zip',
#   'i04ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04ez2.tif.zip',
#   'i04fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04fn2.tif.zip',
#   'i04fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04fz1.tif.zip',
#   'i04fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04fz2.tif.zip',
#   'i04gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04gn1.tif.zip',
#   'i04gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04gn2.tif.zip',
#   'i04gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i04gz1.tif.zip',
#   'i05an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05an1.tif.zip',
#   'i05an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05an2.tif.zip',
#   'i05bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05bn1.tif.zip',
#   'i05dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05dn2.tif.zip',
#   'i05dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05dz2.tif.zip',
#   'i05ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05ez2.tif.zip',
#   'i05fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05fn1.tif.zip',
#   'i05fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05fn2.tif.zip',
#   'i05fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05fz1.tif.zip',
#   'i05fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05fz2.tif.zip',
#   'i05gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05gn1.tif.zip',
#   'i05gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05gn2.tif.zip',
#   'i05gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05gz1.tif.zip',
#   'i05gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05gz2.tif.zip',
#   'i05hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05hn1.tif.zip',
#   'i05hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05hn2.tif.zip',
#   'i05hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05hz1.tif.zip',
#   'i05hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i05hz2.tif.zip',
#   'i06an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06an1.tif.zip',
#   'i06an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06an2.tif.zip',
#   'i06az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06az1.tif.zip',
#   'i06az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06az2.tif.zip',
#   'i06bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06bn1.tif.zip',
#   'i06bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06bn2.tif.zip',
#   'i06bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06bz1.tif.zip',
#   'i06bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06bz2.tif.zip',
#   'i06cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06cn1.tif.zip',
#   'i06cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06cn2.tif.zip',
#   'i06cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06cz1.tif.zip',
#   'i06cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06cz2.tif.zip',
#   'i06dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06dn1.tif.zip',
#   'i06dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06dn2.tif.zip',
#   'i06dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06dz1.tif.zip',
#   'i06dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06dz2.tif.zip',
#   'i06en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06en1.tif.zip',
#   'i06en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06en2.tif.zip',
#   'i06ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06ez1.tif.zip',
#   'i06ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06ez2.tif.zip',
#   'i06fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06fn1.tif.zip',
#   'i06fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06fn2.tif.zip',
#   'i06fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06fz1.tif.zip',
#   'i06fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06fz2.tif.zip',
#   'i06gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06gn1.tif.zip',
#   'i06gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06gn2.tif.zip',
#   'i06gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06gz1.tif.zip',
#   'i06gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06gz2.tif.zip',
#   'i06hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06hn1.tif.zip',
#   'i06hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06hn2.tif.zip',
#   'i06hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06hz1.tif.zip',
#   'i06hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i06hz2.tif.zip',
#   'i07an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07an1.tif.zip',
#   'i07an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07an2.tif.zip',
#   'i07az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07az1.tif.zip',
#   'i07az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07az2.tif.zip',
#   'i07bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07bn1.tif.zip',
#   'i07bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07bn2.tif.zip',
#   'i07bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07bz1.tif.zip',
#   'i07bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07bz2.tif.zip',
#   'i07cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07cn1.tif.zip',
#   'i07cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07cn2.tif.zip',
#   'i07cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07cz1.tif.zip',
#   'i07cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07cz2.tif.zip',
#   'i07dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07dn1.tif.zip',
#   'i07dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07dn2.tif.zip',
#   'i07dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07dz1.tif.zip',
#   'i07dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07dz2.tif.zip',
#   'i07en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07en1.tif.zip',
#   'i07en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07en2.tif.zip',
#   'i07ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07ez1.tif.zip',
#   'i07ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07ez2.tif.zip',
#   'i07fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07fn1.tif.zip',
#   'i07fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07fn2.tif.zip',
#   'i07fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07fz1.tif.zip',
#   'i07fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07fz2.tif.zip',
#   'i07gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07gn1.tif.zip',
#   'i07gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07gn2.tif.zip',
#   'i07gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07gz1.tif.zip',
#   'i07gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07gz2.tif.zip',
#   'i07hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07hn1.tif.zip',
#   'i07hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07hn2.tif.zip',
#   'i07hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07hz1.tif.zip',
#   'i07hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i07hz2.tif.zip',
#   'i08an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08an1.tif.zip',
#   'i08az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08az1.tif.zip',
#   'i08az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08az2.tif.zip',
#   'i08cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08cn1.tif.zip',
#   'i08cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08cn2.tif.zip',
#   'i08cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08cz1.tif.zip',
#   'i08cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08cz2.tif.zip',
#   'i08dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08dn1.tif.zip',
#   'i08dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08dn2.tif.zip',
#   'i08dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08dz1.tif.zip',
#   'i08dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i08dz2.tif.zip',
#   'i09az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09az2.tif.zip',
#   'i09bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09bn1.tif.zip',
#   'i09bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09bn2.tif.zip',
#   'i09bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09bz1.tif.zip',
#   'i09bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09bz2.tif.zip',
#   'i09cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09cn2.tif.zip',
#   'i09cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09cz2.tif.zip',
#   'i09dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09dn1.tif.zip',
#   'i09dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09dn2.tif.zip',
#   'i09dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09dz1.tif.zip',
#   'i09dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09dz2.tif.zip',
#   'i09en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09en1.tif.zip',
#   'i09ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09ez1.tif.zip',
#   'i09gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09gz2.tif.zip',
#   'i09hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09hn2.tif.zip',
#   'i09hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09hz1.tif.zip',
#   'i09hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i09hz2.tif.zip',
#   'i10az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10az2.tif.zip',
#   'i10bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10bn1.tif.zip',
#   'i10bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10bn2.tif.zip',
#   'i10bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10bz1.tif.zip',
#   'i10bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10bz2.tif.zip',
#   'i10cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10cn1.tif.zip',
#   'i10cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10cn2.tif.zip',
#   'i10dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10dn1.tif.zip',
#   'i10dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10dn2.tif.zip',
#   'i10dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10dz2.tif.zip',
#   'i10en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10en1.tif.zip',
#   'i10en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10en2.tif.zip',
#   'i10ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10ez1.tif.zip',
#   'i10ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10ez2.tif.zip',
#   'i10fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10fn1.tif.zip',
#   'i10fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10fn2.tif.zip',
#   'i10fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10fz1.tif.zip',
#   'i10fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10fz2.tif.zip',
#   'i10gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10gn1.tif.zip',
#   'i10gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10gn2.tif.zip',
#   'i10gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10gz1.tif.zip',
#   'i10gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10gz2.tif.zip',
#   'i10hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10hn1.tif.zip',
#   'i10hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10hn2.tif.zip',
#   'i10hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10hz1.tif.zip',
#   'i10hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i10hz2.tif.zip',
#   'i11an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11an1.tif.zip',
#   'i11an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11an2.tif.zip',
#   'i11az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11az1.tif.zip',
#   'i11az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11az2.tif.zip',
#   'i11bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11bn1.tif.zip',
#   'i11bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11bn2.tif.zip',
#   'i11bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11bz1.tif.zip',
#   'i11bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11bz2.tif.zip',
#   'i11cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11cn1.tif.zip',
#   'i11cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11cn2.tif.zip',
#   'i11cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11cz1.tif.zip',
#   'i11cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11cz2.tif.zip',
#   'i11dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11dn1.tif.zip',
#   'i11dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11dn2.tif.zip',
#   'i11dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11dz1.tif.zip',
#   'i11dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11dz2.tif.zip',
#   'i11en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11en1.tif.zip',
#   'i11en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11en2.tif.zip',
#   'i11ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11ez1.tif.zip',
#   'i11ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11ez2.tif.zip',
#   'i11fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11fn1.tif.zip',
#   'i11fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11fn2.tif.zip',
#   'i11fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11fz1.tif.zip',
#   'i11fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11fz2.tif.zip',
#   'i11gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11gn1.tif.zip',
#   'i11gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11gn2.tif.zip',
#   'i11gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11gz1.tif.zip',
#   'i11gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11gz2.tif.zip',
#   'i11hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11hn1.tif.zip',
#   'i11hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11hn2.tif.zip',
#   'i11hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11hz1.tif.zip',
#   'i11hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i11hz2.tif.zip',
#   'i12an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12an1.tif.zip',
#   'i12an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12an2.tif.zip',
#   'i12az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12az1.tif.zip',
#   'i12az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12az2.tif.zip',
#   'i12bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12bn1.tif.zip',
#   'i12bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12bn2.tif.zip',
#   'i12bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12bz1.tif.zip',
#   'i12bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12bz2.tif.zip',
#   'i12cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12cn1.tif.zip',
#   'i12cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12cn2.tif.zip',
#   'i12cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12cz1.tif.zip',
#   'i12cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12cz2.tif.zip',
#   'i12dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12dn1.tif.zip',
#   'i12dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12dn2.tif.zip',
#   'i12dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12dz1.tif.zip',
#   'i12dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12dz2.tif.zip',
#   'i12en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12en1.tif.zip',
#   'i12en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12en2.tif.zip',
#   'i12ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12ez1.tif.zip',
#   'i12ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12ez2.tif.zip',
#   'i12fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12fn1.tif.zip',
#   'i12fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12fn2.tif.zip',
#   'i12fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12fz1.tif.zip',
#   'i12fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12fz2.tif.zip',
#   'i12gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12gn1.tif.zip',
#   'i12gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12gn2.tif.zip',
#   'i12gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12gz1.tif.zip',
#   'i12gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12gz2.tif.zip',
#   'i12hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12hn1.tif.zip',
#   'i12hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12hn2.tif.zip',
#   'i12hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12hz1.tif.zip',
#   'i12hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i12hz2.tif.zip',
#   'i13an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13an1.tif.zip',
#   'i13an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13an2.tif.zip',
#   'i13az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13az1.tif.zip',
#   'i13az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13az2.tif.zip',
#   'i13bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13bn1.tif.zip',
#   'i13bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13bn2.tif.zip',
#   'i13bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13bz1.tif.zip',
#   'i13bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13bz2.tif.zip',
#   'i13cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13cn1.tif.zip',
#   'i13cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13cn2.tif.zip',
#   'i13cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13cz1.tif.zip',
#   'i13cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13cz2.tif.zip',
#   'i13dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13dn1.tif.zip',
#   'i13dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13dn2.tif.zip',
#   'i13dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13dz1.tif.zip',
#   'i13dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i13dz2.tif.zip',
#   'i14an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14an2.tif.zip',
#   'i14az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14az2.tif.zip',
#   'i14bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14bn1.tif.zip',
#   'i14bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14bn2.tif.zip',
#   'i14bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14bz1.tif.zip',
#   'i14bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14bz2.tif.zip',
#   'i14cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14cn2.tif.zip',
#   'i14cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14cz1.tif.zip',
#   'i14cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14cz2.tif.zip',
#   'i14dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14dn1.tif.zip',
#   'i14dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14dn2.tif.zip',
#   'i14dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14dz1.tif.zip',
#   'i14dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14dz2.tif.zip',
#   'i14en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14en1.tif.zip',
#   'i14en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14en2.tif.zip',
#   'i14ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14ez1.tif.zip',
#   'i14ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14ez2.tif.zip',
#   'i14fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14fn1.tif.zip',
#   'i14fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14fz1.tif.zip',
#   'i14fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14fz2.tif.zip',
#   'i14gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14gn1.tif.zip',
#   'i14gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14gn2.tif.zip',
#   'i14gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14gz1.tif.zip',
#   'i14gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14gz2.tif.zip',
#   'i14hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14hn1.tif.zip',
#   'i14hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14hn2.tif.zip',
#   'i14hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14hz1.tif.zip',
#   'i14hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i14hz2.tif.zip',
#   'i15bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15bn1.tif.zip',
#   'i15bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15bn2.tif.zip',
#   'i15bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15bz1.tif.zip',
#   'i15bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15bz2.tif.zip',
#   'i15cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15cz1.tif.zip',
#   'i15cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15cz2.tif.zip',
#   'i15en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15en1.tif.zip',
#   'i15en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15en2.tif.zip',
#   'i15ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15ez1.tif.zip',
#   'i15ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15ez2.tif.zip',
#   'i15fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15fn1.tif.zip',
#   'i15fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15fn2.tif.zip',
#   'i15fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15fz1.tif.zip',
#   'i15fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15fz2.tif.zip',
#   'i15gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15gn2.tif.zip',
#   'i15gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15gz2.tif.zip',
#   'i15hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15hn1.tif.zip',
#   'i15hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15hn2.tif.zip',
#   'i15hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15hz1.tif.zip',
#   'i15hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i15hz2.tif.zip',
#   'i16an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16an1.tif.zip',
#   'i16an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16an2.tif.zip',
#   'i16az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16az1.tif.zip',
#   'i16az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16az2.tif.zip',
#   'i16bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16bn1.tif.zip',
#   'i16bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16bn2.tif.zip',
#   'i16bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16bz1.tif.zip',
#   'i16bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16bz2.tif.zip',
#   'i16cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16cn1.tif.zip',
#   'i16cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16cn2.tif.zip',
#   'i16cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16cz1.tif.zip',
#   'i16cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16cz2.tif.zip',
#   'i16dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16dn1.tif.zip',
#   'i16dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16dn2.tif.zip',
#   'i16dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16dz1.tif.zip',
#   'i16dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16dz2.tif.zip',
#   'i16en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16en1.tif.zip',
#   'i16en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16en2.tif.zip',
#   'i16ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16ez1.tif.zip',
#   'i16ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16ez2.tif.zip',
#   'i16fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16fn1.tif.zip',
#   'i16fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16fn2.tif.zip',
#   'i16fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16fz1.tif.zip',
#   'i16fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16fz2.tif.zip',
#   'i16gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16gn1.tif.zip',
#   'i16gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16gn2.tif.zip',
#   'i16gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16gz1.tif.zip',
#   'i16gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16gz2.tif.zip',
#   'i16hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16hn1.tif.zip',
#   'i16hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16hn2.tif.zip',
#   'i16hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16hz1.tif.zip',
#   'i16hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i16hz2.tif.zip',
#   'i17an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17an1.tif.zip',
#   'i17an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17an2.tif.zip',
#   'i17az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17az1.tif.zip',
#   'i17az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17az2.tif.zip',
#   'i17bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17bn1.tif.zip',
#   'i17bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17bn2.tif.zip',
#   'i17bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17bz1.tif.zip',
#   'i17bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17bz2.tif.zip',
#   'i17cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17cn1.tif.zip',
#   'i17cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17cn2.tif.zip',
#   'i17cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17cz1.tif.zip',
#   'i17cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17cz2.tif.zip',
#   'i17dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17dn1.tif.zip',
#   'i17dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17dn2.tif.zip',
#   'i17dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17dz1.tif.zip',
#   'i17dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17dz2.tif.zip',
#   'i17en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17en1.tif.zip',
#   'i17en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17en2.tif.zip',
#   'i17ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17ez1.tif.zip',
#   'i17ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17ez2.tif.zip',
#   'i17fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17fn1.tif.zip',
#   'i17fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17fn2.tif.zip',
#   'i17fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17fz1.tif.zip',
#   'i17fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17fz2.tif.zip',
#   'i17gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17gn1.tif.zip',
#   'i17gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17gn2.tif.zip',
#   'i17gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17gz1.tif.zip',
#   'i17gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17gz2.tif.zip',
#   'i17hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17hn1.tif.zip',
#   'i17hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17hn2.tif.zip',
#   'i17hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17hz1.tif.zip',
#   'i17hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i17hz2.tif.zip',
#   'i18an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18an1.tif.zip',
#   'i18an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18an2.tif.zip',
#   'i18az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18az1.tif.zip',
#   'i18az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18az2.tif.zip',
#   'i18bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18bn1.tif.zip',
#   'i18bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18bz1.tif.zip',
#   'i18cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18cn1.tif.zip',
#   'i18cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18cn2.tif.zip',
#   'i18cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18cz1.tif.zip',
#   'i18cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i18cz2.tif.zip',
#   'i19an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19an1.tif.zip',
#   'i19an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19an2.tif.zip',
#   'i19az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19az1.tif.zip',
#   'i19az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19az2.tif.zip',
#   'i19bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19bn1.tif.zip',
#   'i19bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19bn2.tif.zip',
#   'i19bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19bz1.tif.zip',
#   'i19bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19bz2.tif.zip',
#   'i19cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19cn1.tif.zip',
#   'i19cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19cn2.tif.zip',
#   'i19cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19cz1.tif.zip',
#   'i19cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19cz2.tif.zip',
#   'i19dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19dn1.tif.zip',
#   'i19dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19dn2.tif.zip',
#   'i19dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19dz1.tif.zip',
#   'i19dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19dz2.tif.zip',
#   'i19en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19en1.tif.zip',
#   'i19en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19en2.tif.zip',
#   'i19ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19ez1.tif.zip',
#   'i19ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19ez2.tif.zip',
#   'i19fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19fn1.tif.zip',
#   'i19fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19fn2.tif.zip',
#   'i19fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19fz1.tif.zip',
#   'i19fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19fz2.tif.zip',
#   'i19gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19gn1.tif.zip',
#   'i19gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19gn2.tif.zip',
#   'i19gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19gz1.tif.zip',
#   'i19gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19gz2.tif.zip',
#   'i19hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19hn1.tif.zip',
#   'i19hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19hz1.tif.zip',
#   'i19hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i19hz2.tif.zip',
#   'i20an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20an1.tif.zip',
#   'i20an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20an2.tif.zip',
#   'i20az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20az1.tif.zip',
#   'i20bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20bn1.tif.zip',
#   'i20bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20bn2.tif.zip',
#   'i20bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20bz1.tif.zip',
#   'i20bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20bz2.tif.zip',
#   'i20dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20dn2.tif.zip',
#   'i20dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20dz1.tif.zip',
#   'i20dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20dz2.tif.zip',
#   'i20en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20en2.tif.zip',
#   'i20ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20ez2.tif.zip',
#   'i20fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20fn1.tif.zip',
#   'i20fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20fn2.tif.zip',
#   'i20fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20fz1.tif.zip',
#   'i20fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20fz2.tif.zip',
#   'i20gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20gn1.tif.zip',
#   'i20gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20gn2.tif.zip',
#   'i20gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20gz1.tif.zip',
#   'i20gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20gz2.tif.zip',
#   'i20hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20hn1.tif.zip',
#   'i20hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20hn2.tif.zip',
#   'i20hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20hz1.tif.zip',
#   'i20hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i20hz2.tif.zip',
#   'i21an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21an1.tif.zip',
#   'i21an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21an2.tif.zip',
#   'i21az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21az1.tif.zip',
#   'i21az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21az2.tif.zip',
#   'i21bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21bn1.tif.zip',
#   'i21bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21bn2.tif.zip',
#   'i21bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21bz1.tif.zip',
#   'i21bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21bz2.tif.zip',
#   'i21cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21cn1.tif.zip',
#   'i21cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21cn2.tif.zip',
#   'i21cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21cz1.tif.zip',
#   'i21cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21cz2.tif.zip',
#   'i21dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21dn1.tif.zip',
#   'i21dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21dn2.tif.zip',
#   'i21dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21dz1.tif.zip',
#   'i21dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21dz2.tif.zip',
#   'i21en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21en1.tif.zip',
#   'i21en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21en2.tif.zip',
#   'i21ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21ez1.tif.zip',
#   'i21ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21ez2.tif.zip',
#   'i21fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21fn1.tif.zip',
#   'i21fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21fn2.tif.zip',
#   'i21fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21fz1.tif.zip',
#   'i21fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21fz2.tif.zip',
#   'i21gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21gn1.tif.zip',
#   'i21gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21gn2.tif.zip',
#   'i21gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21gz1.tif.zip',
#   'i21gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21gz2.tif.zip',
#   'i21hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21hn1.tif.zip',
#   'i21hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21hn2.tif.zip',
#   'i21hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21hz1.tif.zip',
#   'i21hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i21hz2.tif.zip',
#   'i22an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22an1.tif.zip',
#   'i22an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22an2.tif.zip',
#   'i22az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22az1.tif.zip',
#   'i22az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22az2.tif.zip',
#   'i22bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22bn1.tif.zip',
#   'i22bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22bn2.tif.zip',
#   'i22bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22bz1.tif.zip',
#   'i22bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22bz2.tif.zip',
#   'i22cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22cn1.tif.zip',
#   'i22cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22cn2.tif.zip',
#   'i22cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22cz1.tif.zip',
#   'i22cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22cz2.tif.zip',
#   'i22dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22dn1.tif.zip',
#   'i22dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22dn2.tif.zip',
#   'i22dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22dz1.tif.zip',
#   'i22dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22dz2.tif.zip',
#   'i22en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22en1.tif.zip',
#   'i22en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22en2.tif.zip',
#   'i22ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22ez1.tif.zip',
#   'i22ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22ez2.tif.zip',
#   'i22fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22fn1.tif.zip',
#   'i22fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22fn2.tif.zip',
#   'i22fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22fz1.tif.zip',
#   'i22fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22fz2.tif.zip',
#   'i22gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_05m_int/i22gn1.tif.zip',
# ...
#   'u38bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38bz1.laz.zip',
#   'u38bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38bz2.laz.zip',
#   'u38cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38cn1.laz.zip',
#   'u38cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38cn2.laz.zip',
#   'u38cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38cz1.laz.zip',
#   'u38cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38cz2.laz.zip',
#   'u38dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38dn1.laz.zip',
#   'u38dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38dn2.laz.zip',
#   'u38dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38dz1.laz.zip',
#   'u38dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38dz2.laz.zip',
#   'u38en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38en1.laz.zip',
#   'u38en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38en2.laz.zip',
#   'u38ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38ez1.laz.zip',
#   'u38ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38ez2.laz.zip',
#   'u38fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38fn1.laz.zip',
#   'u38fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38fn2.laz.zip',
#   'u38fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38fz1.laz.zip',
#   'u38fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38fz2.laz.zip',
#   'u38gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38gn1.laz.zip',
#   'u38gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38gn2.laz.zip',
#   'u38gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38gz1.laz.zip',
#   'u38gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38gz2.laz.zip',
#   'u38hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38hn1.laz.zip',
#   'u38hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38hn2.laz.zip',
#   'u38hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38hz1.laz.zip',
#   'u38hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u38hz2.laz.zip',
#   'u39an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39an1.laz.zip',
#   'u39an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39an2.laz.zip',
#   'u39az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39az1.laz.zip',
#   'u39az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39az2.laz.zip',
#   'u39bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39bn1.laz.zip',
#   'u39bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39bn2.laz.zip',
#   'u39bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39bz1.laz.zip',
#   'u39bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39bz2.laz.zip',
#   'u39cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39cn1.laz.zip',
#   'u39cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39cn2.laz.zip',
#   'u39cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39cz1.laz.zip',
#   'u39cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39cz2.laz.zip',
#   'u39dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39dn1.laz.zip',
#   'u39dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39dn2.laz.zip',
#   'u39dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39dz1.laz.zip',
#   'u39dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39dz2.laz.zip',
#   'u39en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39en1.laz.zip',
#   'u39en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39en2.laz.zip',
#   'u39ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39ez1.laz.zip',
#   'u39ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39ez2.laz.zip',
#   'u39fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39fn1.laz.zip',
#   'u39fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39fn2.laz.zip',
#   'u39fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39fz1.laz.zip',
#   'u39fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39fz2.laz.zip',
#   'u39gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39gn1.laz.zip',
#   'u39gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39gn2.laz.zip',
#   'u39gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39gz1.laz.zip',
#   'u39gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39gz2.laz.zip',
#   'u39hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39hn1.laz.zip',
#   'u39hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39hn2.laz.zip',
#   'u39hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39hz1.laz.zip',
#   'u39hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u39hz2.laz.zip',
#   'u40an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40an1.laz.zip',
#   'u40an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40an2.laz.zip',
#   'u40az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40az1.laz.zip',
#   'u40az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40az2.laz.zip',
#   'u40bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40bn1.laz.zip',
#   'u40bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40bn2.laz.zip',
#   'u40bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40bz1.laz.zip',
#   'u40bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40bz2.laz.zip',
#   'u40cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40cn1.laz.zip',
#   'u40cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40cn2.laz.zip',
#   'u40cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40cz1.laz.zip',
#   'u40cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40cz2.laz.zip',
#   'u40dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40dn1.laz.zip',
#   'u40dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40dn2.laz.zip',
#   'u40dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40dz1.laz.zip',
#   'u40dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40dz2.laz.zip',
#   'u40en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40en1.laz.zip',
#   'u40en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40en2.laz.zip',
#   'u40ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40ez1.laz.zip',
#   'u40ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40ez2.laz.zip',
#   'u40fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40fn1.laz.zip',
#   'u40fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40fn2.laz.zip',
#   'u40fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40fz1.laz.zip',
#   'u40fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40fz2.laz.zip',
#   'u40gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40gn1.laz.zip',
#   'u40gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40gn2.laz.zip',
#   'u40gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40gz1.laz.zip',
#   'u40gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40gz2.laz.zip',
#   'u40hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40hn1.laz.zip',
#   'u40hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40hn2.laz.zip',
#   'u40hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40hz1.laz.zip',
#   'u40hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u40hz2.laz.zip',
#   'u41an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41an1.laz.zip',
#   'u41an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41an2.laz.zip',
#   'u41az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41az1.laz.zip',
#   'u41az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41az2.laz.zip',
#   'u41bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41bn1.laz.zip',
#   'u41bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41bn2.laz.zip',
#   'u41bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41bz1.laz.zip',
#   'u41bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41bz2.laz.zip',
#   'u41cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41cn1.laz.zip',
#   'u41cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41cn2.laz.zip',
#   'u41cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41cz1.laz.zip',
#   'u41cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41cz2.laz.zip',
#   'u41dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41dn1.laz.zip',
#   'u41dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41dn2.laz.zip',
#   'u41dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41dz1.laz.zip',
#   'u41en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41en1.laz.zip',
#   'u41en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41en2.laz.zip',
#   'u41ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41ez1.laz.zip',
#   'u41ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41ez2.laz.zip',
#   'u41fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41fn1.laz.zip',
#   'u41fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41fz1.laz.zip',
#   'u41gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41gn1.laz.zip',
#   'u41gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41gn2.laz.zip',
#   'u41hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u41hn1.laz.zip',
#   'u43an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43an1.laz.zip',
#   'u43an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43an2.laz.zip',
#   'u43az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43az1.laz.zip',
#   'u43az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43az2.laz.zip',
#   'u43bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43bn1.laz.zip',
#   'u43bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43bn2.laz.zip',
#   'u43bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43bz1.laz.zip',
#   'u43bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43bz2.laz.zip',
#   'u43cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43cn1.laz.zip',
#   'u43cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43cn2.laz.zip',
#   'u43cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43cz1.laz.zip',
#   'u43cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43cz2.laz.zip',
#   'u43dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43dn1.laz.zip',
#   'u43dn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43dn2.laz.zip',
#   'u43dz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43dz1.laz.zip',
#   'u43dz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43dz2.laz.zip',
#   'u43en1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43en1.laz.zip',
#   'u43en2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43en2.laz.zip',
#   'u43ez1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43ez1.laz.zip',
#   'u43ez2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43ez2.laz.zip',
#   'u43fn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43fn1.laz.zip',
#   'u43fn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43fn2.laz.zip',
#   'u43fz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43fz1.laz.zip',
#   'u43fz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43fz2.laz.zip',
#   'u43gn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43gn1.laz.zip',
#   'u43gn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43gn2.laz.zip',
#   'u43gz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43gz1.laz.zip',
#   'u43gz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43gz2.laz.zip',
#   'u43hn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43hn1.laz.zip',
#   'u43hn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43hn2.laz.zip',
#   'u43hz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43hz1.laz.zip',
#   'u43hz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u43hz2.laz.zip',
#   'u44an1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44an1.laz.zip',
#   'u44an2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44an2.laz.zip',
#   'u44az1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44az1.laz.zip',
#   'u44az2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44az2.laz.zip',
#   'u44bn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44bn1.laz.zip',
#   'u44bn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44bn2.laz.zip',
#   'u44bz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44bz1.laz.zip',
#   'u44bz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44bz2.laz.zip',
#   'u44cn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44cn1.laz.zip',
#   'u44cn2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44cn2.laz.zip',
#   'u44cz1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44cz1.laz.zip',
#   'u44cz2': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44cz2.laz.zip',
#   'u44dn1': 'http://geodata.nationaalgeoregister.nl/ahn2/extract/ahn2_uitgefilterd/u44dn1.laz.zip',
#   ...}}

# %% [markdown]
# ## Execute : Launch downloading on the server

# %% [raw]
# #This loop is used when we want to download all the files on the server
# #Careful it could be long
# for dataset in datasets_links:
#     print(dataset)
#     for filename in datasets_links[dataset]:
#         print(filename, datasets_links[dataset][filename])
#         call_script_sh(filename,datasets_links[dataset][filename])

# %% [markdown]
# ## If you have an error during the download

# %% [markdown]
# ### Restart the download of files in a specific dataset

# %% [raw]
# #Continue the downloading of the first dataset which crashed during the night
# flag = 0
# dataset = datasets_links["http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_gefilterd.xml"] #Dataset linj
#
# for filename in dataset:
#     if flag == 1:
#     call_script_sh(filename, dataset[filename])
#
#     if filename == 'i52bn2': #Here you can change the filename
#         flag = 1

# %% [markdown]
# ### Download one dataset from its link

# %% [raw]
# #Use the link of the xml : all the link are in the "download_links" variable
# dataset = datasets_links["http://geodata.nationaalgeoregister.nl/ahn2/atom/ahn2_gefilterd.xml"]
#
# for filename in dataset:
#     call_script_sh(filename, dataset[filename])

# %% [markdown]
# # References

# %% [markdown]
# General datasets page : https://www.pdok.nl/datasets
#
#
# Dataset we are using : Actueel Hoogtebestand Nederland (AHN2)
#
#
# Link to this dataset : https://www.pdok.nl/downloads?articleid=1948857
